# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# %% [markdown]
# 1. Relational Plot

# %%
tips=sns.load_dataset('tips')
tips.sample(3)
# Out:
#      total_bill   tip   sex smoker   day    time  size
# 192       28.44  2.56  Male    Yes  Thur   Lunch     2
# 65        20.08  3.15  Male     No   Sat  Dinner     3
# 70        12.02  1.97  Male     No   Sat  Dinner     2

# %%
#Scatter Plot:
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',hue='sex',style='smoker')

plt.show()

# %%
#Scatter Plot: (#Facet Plot)
sns.relplot(data=tips,x='total_bill',y='tip',kind='scatter',col='sex',color='red')

plt.show()

# %%
import plotly.express as px
gap = px.data.gapminder()
gap.sample(3)
# Out:
#         country continent  year  lifeExp        pop    gdpPercap iso_alpha  \
# 712   Indonesia      Asia  1972   49.203  121282000  1111.107907       IDN
# 915  Madagascar    Africa  1967   42.881    6334556  1634.047282       MDG
# 621      Guinea    Africa  1997   51.455    8048834   869.449767       GIN
#
#      iso_num
# 712      360
# 915      450
# 621      324

# %%
nepal=gap[gap['country']=="Nepal"]

# %%
#Line Plot
sns.relplot(data=nepal,x='year',y='lifeExp',kind='line')

plt.show()

# %%
three_countries=gap[gap['country'].isin(['Nepal','Chad','Sao Tome and Principe'])]
three_countries
# Out:
#                     country continent  year  lifeExp       pop    gdpPercap  \
# 264                    Chad    Africa  1952   38.092   2682462  1178.665927
# 265                    Chad    Africa  1957   39.881   2894855  1308.495577
# 266                    Chad    Africa  1962   41.716   3150417  1389.817618
# 267                    Chad    Africa  1967   43.601   3495967  1196.810565
# 268                    Chad    Africa  1972   45.569   3899068  1104.103987
# 269                    Chad    Africa  1977   47.383   4388260  1133.984950
# 270                    Chad    Africa  1982   49.517   4875118   797.908101
# 271                    Chad    Africa  1987   51.051   5498955   952.386129
# 272                    Chad    Africa  1992   51.724   6429417  1058.064300
# 273                    Chad    Africa  1997   51.573   7562011  1004.961353
# 274                    Chad    Africa  2002   50.525   8835739  1156.181860
# 275                    Chad    Africa  2007   50.651  10238807  1704.063724
# 1068                  Nepal      Asia  1952   36.157   9182536   545.865723
# 1069                  Nepal      Asia  1957   37.686   9682338   597.936356
# 1070                  Nepal      Asia  1962   39.393  10332057   652.396859
# 1071                  Nepal      Asia  1967   41.472  11261690   676.442225
# 1072                  Nepal      Asia  1972   43.971  12412593   674.788130
# 1073                  Nepal      Asia  1977   46.748  13933198   694.112440
# 1074                  Nepal      Asia  1982   49.594  15796314   718.373095
# 1075                  Nepal      Asia  1987   52.537  17917180   775.632450
# 1076                  Nepal      Asia  1992   55.727  20326209   897.740360
# 1077                  Nepal      Asia  1997   59.426  23001113  1010.892138
# 1078                  Nepal      Asia  2002   61.340  25873917  1057.206311
# 1079                  Nepal      Asia  2007   63.785  28901790  1091.359778
# 1296  Sao Tome and Principe    Africa  1952   46.471     60011   879.583586
# 1297  Sao Tome and Principe    Africa  1957   48.945     61325   860.736903
# 1298  Sao Tome and Principe    Africa  1962   51.893     65345  1071.551119
# 1299  Sao Tome and Principe    Africa  1967   54.425     70787  1384.840593
# 1300  Sao Tome and Principe    Africa  1972   56.480     76595  1532.985254
# 1301  Sao Tome and Principe    Africa  1977   58.550     86796  1737.561657
# 1302  Sao Tome and Principe    Africa  1982   60.351     98593  1890.218117
# 1303  Sao Tome and Principe    Africa  1987   61.728    110812  1516.525457
# 1304  Sao Tome and Principe    Africa  1992   62.742    125911  1428.777814
# 1305  Sao Tome and Principe    Africa  1997   63.306    145608  1339.076036
# 1306  Sao Tome and Principe    Africa  2002   64.337    170372  1353.092390
# 1307  Sao Tome and Principe    Africa  2007   65.528    199579  1598.435089
#
#      iso_alpha  iso_num
# 264        TCD      148
# 265        TCD      148
# 266        TCD      148
# 267        TCD      148
# 268        TCD      148
# 269        TCD      148
# 270        TCD      148
# 271        TCD      148
# 272        TCD      148
# 273        TCD      148
# 274        TCD      148
# 275        TCD      148
# 1068       NPL      524
# 1069       NPL      524
# 1070       NPL      524
# 1071       NPL      524
# 1072       NPL      524
# 1073       NPL      524
# 1074       NPL      524
# 1075       NPL      524
# 1076       NPL      524
# 1077       NPL      524
# 1078       NPL      524
# 1079       NPL      524
# 1296       STP      678
# 1297       STP      678
# 1298       STP      678
# 1299       STP      678
# 1300       STP      678
# 1301       STP      678
# 1302       STP      678
# 1303       STP      678
# 1304       STP      678
# 1305       STP      678
# 1306       STP      678
# 1307       STP      678

# %%
sns.relplot(data=three_countries,x='year',y='lifeExp',kind='line',hue='country')

plt.show()

# %% [markdown]
# 2. Distribution Plot

# %%
tips.sample(3)
# Out:
#     total_bill   tip     sex smoker   day    time  size
# 64       17.59  2.64    Male     No   Sat  Dinner     3
# 81       16.66  3.40    Male     No  Thur   Lunch     2
# 32       15.06  3.00  Female     No   Sat  Dinner     2

# %%
#Histogram
sns.displot(data=tips,x='total_bill',kind='hist')

plt.show()

# %%
sns.displot(data=tips,x='total_bill',col='sex',kind='hist',color='purple')

plt.show()

# %%
sns.displot(data=tips,x='tip',kind='kde',color='red')
sns.rugplot(data=tips,x='tip')

plt.show()

# %% [markdown]
# 3. Categorical Plot

# %%
sns.catplot(data=tips,x='day',y='total_bill')

plt.show()

# %%
sns.catplot(data=tips,x='day',y='tip',kind='box')

plt.show()

# %%
sns.catplot(data=tips,x='day',y='tip',kind='box',hue='sex')

plt.show()

# %%
sns.catplot(data=tips,x='smoker',kind='count',color='red')

plt.show()
